# %% [markdown]
# ### Configuração da API do Gemini no Google Colab
#
# Este código configura o ambiente do Google Colab para usar a API do Gemini (Google Generative AI) com segurança, utilizando o recurso de **Secrets** para gerenciar a chave de API. Ele também instala as bibliotecas necessárias para geração de conteúdo e busca no Google.
#
# #### O que o código faz:
# 1. **Instalação de Dependências**:
#    - Instala silenciosamente (`-q`) as bibliotecas `google-generativeai` (para a API do Gemini) e `googlesearch-python` (para buscas no Google).
#
# 2. **Importação de Bibliotecas**:
#    - Importa `google.generativeai` como `genai` para interagir com a API.
#    - Usa `userdata` do Colab para acessar segredos.
#    - Importa `search` de `googlesearch` para buscas externas.
#
# 3. **Obtenção da Chave de API**:
#    - Tenta recuperar a chave de API do Gemini do segredo chamado `GOOGLE_API_KEY` (nota: o código espera `GEMINI_API_KEY` na validação, o que pode ser um erro; deve ser consistente).
#    - Levanta um erro se o segredo não for encontrado ou estiver vazio, com instruções para configurá-lo.
#
# 4. **Configuração da API**:
#    - Configura a API do Gemini com a chave obtida usando `genai.configure`.
#
# 5. **Validação da API**:
#    - Testa a conexão com o modelo `"gemini-1.5-flash"` (um modelo leve e rápido, válido em 2025).
#    - Gera um texto simples ("Teste de API") para confirmar que a API está funcionando.
#    - Se falhar, exibe uma mensagem de erro detalhada.
#
# 6. **Instruções de Configuração**:
#    - Fornece um guia passo a passo para adicionar a chave nos Secrets do Colab, exibido independentemente de erro.
#
# #### Notas Importantes:
# - **Nome do Segredo**: O código usa `GOOGLE_API_KEY` para buscar o segredo, mas a validação e as instruções mencionam `GEMINI_API_KEY`. Certifique-se de usar um nome consistente (recomendo `GEMINI_API_KEY`).
# - **Modelo**: `"gemini-1.5-flash"` é uma escolha válida para testes rápidos, mas para tarefas mais complexas, considere `"gemini-1.5-pro"`.
# - **Segurança**: Armazenar a chave nos Secrets evita exposição acidental no código.
#
# #### Como Usar:
# 1. Configure o segredo `GEMINI_API_KEY` com sua chave real (ex.: `AIzaSyClWplmEF8_sDgmSbhg0h6xkAoFQcLU4p4`) na aba Secrets do Colab.
# 2. Execute esta célula antes de qualquer código que dependa da API do Gemini.
# 3. Verifique a mensagem `API do Gemini configurada com sucesso!` para confirmar a configuração.
#
# #### Resolução de Problemas:
# - **Erro de Segredo**: Se aparecer `SecretNotFoundError`, siga as instruções exibidas para adicionar a chave.
# - **Erro 429 (Quota Excedida)**: Aumente sua quota no [Google Cloud Console](https://console.cloud.google.com/) ou adicione delays no uso da API.

# %%
# Instala bibliotecas necessárias
# !pip install -q google-generativeai googlesearch-python

# Importa bibliotecas
import google.generativeai as genai
from google.colab import userdata
from googlesearch import search

# Obtém a chave de API do Gemini a partir dos Secrets
try:
    API_KEY = userdata.get('GOOGLE_API_KEY')  # Nome do segredo no Colab
    if not API_KEY:
        raise ValueError("A chave 'GEMINI_API_KEY' não foi encontrada nos Secrets.")
except userdata.SecretNotFoundError:
    raise ValueError("Por favor, adicione a chave 'GEMINI_API_KEY' nos Secrets do Colab. Veja as instruções abaixo.")

# Configura a API do Gemini
genai.configure(api_key=API_KEY)

# Teste simples para verificar a API
try:
    test_model = genai.GenerativeModel("gemini-1.5-flash")  # Modelo válido em 2025
    test_response = test_model.generate_content("Teste de API")
    print("API do Gemini configurada com sucesso!")
except Exception as e:
    raise ValueError(f"Falha ao validar a API do Gemini: {str(e)}")

# Instruções para adicionar o segredo (aparece apenas se houver erro)
print("""
Como adicionar a chave nos Secrets:
1. No menu à esquerda do Colab, clique no ícone de chave (🔑).
2. Clique em 'Adicionar novo segredo'.
3. Nomeie como 'GEMINI_API_KEY' e cole sua chave (ex.: 'AIzaSyClWplmEF8_sDgmSbhg0h6xkAoFQcLU4p4').
4. Ative 'Acesso ao notebook' e reexecute esta célula.
""")
# Out:
# API do Gemini configurada com sucesso!
#
# Como adicionar a chave nos Secrets:
# 1. No menu à esquerda do Colab, clique no ícone de chave (🔑).
# 2. Clique em 'Adicionar novo segredo'.
# 3. Nomeie como 'GEMINI_API_KEY' e cole sua chave (ex.: 'AIzaSyClWplmEF8_sDgmSbhg0h6xkAoFQcLU4p4').
# 4. Ative 'Acesso ao notebook' e reexecute esta célula.

# %% [markdown]
# ### Mangaba.AI - Implementação de Agentes Colaborativos no Google Colab
#
# Este código implementa o **Mangaba.AI**, um sistema de orquestração de agentes de IA colaborativos projetado para executar tarefas interdependentes de forma assíncrona. Ele utiliza a API do Gemini para geração de conteúdo e integra busca no Google como ferramenta externa, tudo configurado para rodar no Google Colab.
#
# #### Estrutura do Código
# 1. **Importações**:
#    - Inclui `asyncio` para execução assíncrona, `typing` para anotações de tipo, e `dataclasses` para criar a classe `Task`.
#
# 2. **Módulos Principais**:
#    - **`ContextualMemory`**:
#      - Gerencia memória individual por agente (`individual_data`) e memória global compartilhada (`global_data`).
#      - Limita o tamanho do contexto com `max_context_size` (padrão: 10).
#    - **`GeminiModel`**:
#      - Interface com a API do Gemini, configurada com modelo (ex.: `"gemini-1.5-pro"`), `temperature` (criatividade) e `top_k` (diversidade).
#      - Inclui tratamento de erros para falhas na geração de conteúdo.
#    - **`GoogleSearchTool`**:
#      - Ferramenta assíncrona que realiza buscas reais no Google, retornando até 3 resultados.
#    - **`Agent`**:
#      - Define agentes com nome, papel, modelo, ferramentas e memória.
#      - Executa tarefas combinando contexto, dependências e resultados de ferramentas, ajustando respostas curtas (< 50 caracteres).
#    - **`Task`**:
#      - Representa uma tarefa com descrição, agente, prioridade e dependências opcionais.
#      - Usa `executed` para evitar reexecução.
#    - **`Crew`**:
#      - Orquestra os agentes e tarefas, executando-as em ordem de prioridade e respeitando dependências.
#
# 3. **Exemplo de Uso**:
#    - Cria três agentes: `Pesquisador`, `Analista` e `Escritor`.
#    - Define um fluxo de tarefas:
#      1. `Pesquisador`: Busca dados sobre IA na saúde.
#      2. `Analista`: Analisa os dados (depende do Pesquisador).
#      3. `Escritor`: Gera um relatório executivo (depende do Analista).
#    - Executa o fluxo com `Crew`.
#
# #### Pré-requisitos
# - A Célula 1 (configuração da API do Gemini) deve ser executada antes, com a chave `GEMINI_API_KEY` configurada nos Secrets do Colab.
#
# #### Como Executar
# 1. Certifique-se de que a API do Gemini está configurada (Célula 1).
# 2. Copie e execute esta célula no Colab.
# 3. Observe a saída no console, que mostrará a execução e os resultados de cada agente.
#
# #### Exemplo de Saída Esperada

# %%
# Importações
import asyncio
from typing import List, Optional, Dict, Set
from dataclasses import dataclass

# Definição dos módulos

## ContextualMemory (com memória global)
class ContextualMemory:
    def __init__(self, max_context_size: int = 10):
        self.individual_data: Dict[str, List[str]] = {}
        self.global_data: List[str] = []
        self.max_context_size = max_context_size

    def store_individual(self, agent_name: str, content: str):
        agent_history = self.individual_data.setdefault(agent_name, [])
        agent_history.append(content)
        if len(agent_history) > self.max_context_size:
            agent_history.pop(0)

    def store_global(self, content: str):
        self.global_data.append(content)
        if len(self.global_data) > self.max_context_size:
            self.global_data.pop(0)

    def retrieve_individual(self, agent_name: str) -> List[str]:
        return self.individual_data.get(agent_name, [])

    def retrieve_global(self) -> List[str]:
        return self.global_data

## GeminiModel (com tratamento de erro)
class GeminiModel:
    def __init__(self, model_name: str = "gemini-1.5-flash", temperature: float = 0.7, top_k: int = 40):
        self.model = genai.GenerativeModel(model_name)
        self.temperature = temperature
        self.top_k = top_k

    async def generate(self, prompt: str) -> str:
        try:
            await asyncio.sleep(0.5)  # Simula latência
            response = self.model.generate_content(
                prompt,
                generation_config=genai.types.GenerationConfig(
                    temperature=self.temperature,
                    top_k=self.top_k
                )
            )
            return response.text
        except Exception as e:
            return f"Erro na geração: {str(e)}"

## GoogleSearchTool (busca real)
class GoogleSearchTool:
    async def run(self, query: str) -> str:
        await asyncio.sleep(0.3)  # Simula latência de rede
        try:
            results = list(search(query, num_results=3))
            return f"Resultados da busca: {', '.join(results)}"
        except Exception as e:
            return f"Erro na busca: {str(e)}"

## Agent
class Agent:
    def __init__(self, name: str, role: str, model, tools: Optional[List] = None, memory=None):
        self.name = name
        self.role = role
        self.model = model
        self.tools = tools or []
        self.memory = memory

    async def execute(self, input_text: str, dependencies: List[str] = None) -> str:
        print(f"[{self.name}] Executando: {input_text}")

        individual_context = self.memory.retrieve_individual(self.name) if self.memory else []
        global_context = self.memory.retrieve_global() if self.memory else []
        deps_text = f"Dependências: {dependencies}" if dependencies else ""
        enriched_input = (
            f"Contexto individual: {individual_context[-3:]}\n"
            f"Contexto global: {global_context[-3:]}\n"
            f"{deps_text}\nTarefa: {input_text}"
        )

        tool_outputs = []
        for tool in self.tools:
            tool_result = await tool.run(input_text)
            tool_outputs.append(f"[{tool.__class__.__name__}] {tool_result}")

        final_input = f"{enriched_input}\nResultados das ferramentas: {tool_outputs}" if tool_outputs else enriched_input

        response = await self.model.generate(final_input)

        if len(response) < 50:
            response = await self.model.generate(f"{final_input}\nPor favor, forneça mais detalhes.")

        if self.memory:
            self.memory.store_individual(self.name, f"Entrada: {input_text}\nResposta: {response}")
            self.memory.store_global(f"[{self.name}] {response}")

        return response

## Task
@dataclass
class Task:
    description: str
    agent: "Agent"
    priority: int = 0
    dependencies: Optional[List["Task"]] = None
    result: Optional[str] = None
    executed: bool = False  # Controle para evitar reexecução

    def get_dependencies_results(self) -> List[str]:
        if not self.dependencies:
            return []
        return [task.result for task in self.dependencies if task.result]

## Crew (com controle de execução)
class Crew:
    def __init__(self, agents: List[Agent], tasks: List[Task]):
        self.agents = {agent.name: agent for agent in agents}
        self.tasks = sorted(tasks, key=lambda t: t.priority, reverse=True)

    async def run_task(self, task: Task):
        if task.executed:  # Evita executar a mesma tarefa mais de uma vez
            return

        if task.dependencies:
            await asyncio.gather(*(self.run_task(dep) for dep in task.dependencies if not dep.executed))

        agent = self.agents[task.agent.name]
        dependencies_results = task.get_dependencies_results()
        result = await agent.execute(task.description, dependencies_results)
        task.result = result
        task.executed = True  # Marca como executada
        print(f"[{agent.name}] Resultado: {result}")

    async def run(self):
        await asyncio.gather(*(self.run_task(task) for task in self.tasks))

# Exemplo de uso
async def main():
    memory = ContextualMemory(max_context_size=5)
    model = GeminiModel(temperature=0.8, top_k=50)
    search_tool = GoogleSearchTool()

    pesquisador = Agent(name="Pesquisador", role="Busca dados", model=model, tools=[search_tool], memory=memory)
    analista = Agent(name="Analista", role="Analisa dados", model=model, memory=memory)
    escritor = Agent(name="Escritor", role="Escreve relatório", model=model, memory=memory)

    tarefa_pesquisa = Task(description="Buscar dados sobre IA na saúde", agent=pesquisador, priority=2)
    tarefa_analise = Task(description="Analisar os dados encontrados", agent=analista, priority=1, dependencies=[tarefa_pesquisa])
    tarefa_relatorio = Task(description="Gerar relatório executivo", agent=escritor, priority=0, dependencies=[tarefa_analise])

    equipe = Crew(agents=[pesquisador, analista, escritor], tasks=[tarefa_pesquisa, tarefa_analise, tarefa_relatorio])
    await equipe.run()

# Executa no Colab
if __name__ == "__main__":
    await main()
# Out:
# [Pesquisador] Executando: Buscar dados sobre IA na saúde
# [Pesquisador] Executando: Buscar dados sobre IA na saúde
# [Pesquisador] Executando: Buscar dados sobre IA na saúde
# [Pesquisador] Resultado: Os resultados da busca fornecem uma visão inicial sobre a adoção da Inteligência Artificial (IA) na saúde no Brasil.  Podemos extrair as seguintes informações:
#
# * **Baixa Adoção:**  As pesquisas apontam uma adoção relativamente baixa da IA pelos profissionais de saúde no Brasil.  Um estudo citado indica que apenas 17% dos médicos e 16% dos enfermeiros utilizam IA.  Outro estudo menciona que cerca de 4% dos estabelecimentos de saúde utilizam IA.
#
# * **Fontes:** As fontes incluem um artigo do site Upflux (que requer acesso para detalhes), uma notícia do SBIS (Sociedade Brasileira de Informática em Saúde) e uma notícia do G1 (portal de notícias da Globo).  A variedade de fontes sugere alguma credibilidade, mas seria necessário analisar o rigor metodológico de cada estudo para uma avaliação completa.
#
# * **Falta de Detalhes:** Os resultados são superficiais. Faltam informações cruciais, como:
#     * **Tipos de IA utilizados:** Que tipos de aplicações de IA estão sendo usadas (diagnóstico por imagem, análise de dados, assistentes virtuais, etc.)?
#     * **Barreiras à adoção:** Quais são os principais obstáculos à implementação da IA na saúde no Brasil (custos, falta de infraestrutura, regulamentação, falta de treinamento, etc.)?
#     * **Benefícios observados:** Quais são os benefícios relatados pela utilização da IA pelos profissionais e pacientes?
#     * **Região geográfica:** Os dados se referem a todo o Brasil ou a regiões específicas?
#
# **Próximos passos para uma pesquisa mais completa:**
#
# * **Acessar os links fornecidos:**  Ler os artigos completos para obter mais detalhes sobre a metodologia, resultados e conclusões dos estudos.
# * **Buscar mais artigos científicos:** Consultar bases de dados como PubMed, Scopus e Web of Science para encontrar estudos mais aprofundados sobre o tema.
# * **Analisar relatórios de mercado:** Procurar relatórios de empresas de consultoria que analisam o mercado de IA na saúde no Brasil.
# * **Pesquisar diferentes tipos de aplicações de IA na saúde:** Investigar o uso de IA em áreas específicas, como radiologia, oncologia, cardiologia, etc.
#
#
# Em resumo, os resultados iniciais indicam uma utilização limitada da IA na saúde no Brasil, mas são necessários mais dados para uma compreensão completa da situação.
#
# [Pesquisador] Resultado: Os resultados da busca fornecem uma visão inicial sobre a adoção da Inteligência Artificial (IA) na saúde no Brasil.  No entanto, a informação é limitada e requer análise mais aprofundada.  Vamos resumir o que cada link sugere:
#
# * **`https://upflux.net/pt/blog/inteligencia-artificial-na-saude/`**:  Este link provavelmente contém um artigo de blog sobre IA na saúde, mas sem mais detalhes, não podemos saber seu conteúdo específico.  É necessário acessar o link para extrair informações relevantes.
#
# * **`https://sbis.org.br/noticia/estudo-revela-que-17-dos-medicos-no-brasil-utilizam-inteligencia-artificial-o-numero-entre-os-enfermeiros-e-de-16/`**: Este link reporta um estudo que indica que 17% dos médicos e 16% dos enfermeiros no Brasil utilizam IA.  Esta é uma estatística importante que demonstra a penetração da tecnologia, mas falta contexto sobre o tipo de IA utilizada e a abrangência do estudo (tamanho da amostra, metodologia, etc.).
#
# * **`https://g1.globo.com/saude/noticia/2024/10/11/cerca-de-4percent-dos-estabelecimentos-de-saude-e-17percent-dos-medicos-no-brasil-utilizam-ia-aponta-pesquisa.ghtml`**: Este link do G1 corrobora a informação anterior, mas com dados ligeiramente diferentes.  Apresenta 4% dos estabelecimentos de saúde e 17% dos médicos utilizando IA.  Novamente, a falta de detalhes sobre a pesquisa limita a interpretação dos dados.
#
#
# **Conclusões preliminares:**
#
# A adoção de IA na saúde no Brasil parece estar em estágios iniciais, com uma penetração relativamente baixa, pelo menos entre médicos e estabelecimentos de saúde.  As estatísticas apresentadas são conflitantes em certos aspectos (4% vs. 17% de estabelecimentos de saúde), indicando a necessidade de investigar a metodologia dos estudos citados.  Para uma análise mais completa, é necessário acessar e analisar o conteúdo de cada link, procurando informações sobre:
#
# * **Tipos de IA utilizados:**  Diagnóstico por imagem, análise de dados de pacientes, robótica cirúrgica, etc.
# * **Abrangência geográfica:**  A pesquisa abrange todo o Brasil ou apenas regiões específicas?
# * **Metodologia da pesquisa:**  Como os dados foram coletados e analisados?  Qual o tamanho da amostra?
# * **Limitações do estudo:**  Quais são as possíveis fontes de erro ou viés na pesquisa?
#
#
# Em resumo, os resultados fornecem um ponto de partida para a pesquisa, mas mais investigação é necessária para uma compreensão completa do tema.
#
# [Pesquisador] Resultado: Os resultados da busca fornecem uma visão inicial sobre a adoção da Inteligência Artificial (IA) na saúde no Brasil.  No entanto, a informação é fragmentada e requer análise mais aprofundada.  Vejamos o que cada link sugere:
#
# * **upflux.net:** Este link provavelmente fornece uma visão geral sobre a IA na saúde, possivelmente discutindo aplicações e tendências.  Sem acessar o link, não é possível determinar o escopo exato do conteúdo.
#
# * **sbis.org.br:** Este artigo de notícias reporta um estudo mostrando que 17% dos médicos e 16% dos enfermeiros no Brasil utilizam IA.  Isso indica uma penetração relativamente baixa, mas fornece um dado quantitativo importante.  A pesquisa em si precisaria ser analisada para entender a metodologia e as limitações do estudo.
#
# * **g1.globo.com:** Este artigo do G1 corrobora a informação anterior, mencionando cerca de 4% dos estabelecimentos de saúde e 17% dos médicos usando IA no Brasil.  A discrepância entre as porcentagens de médicos que utilizam IA nos dois artigos precisa ser investigada para entender a possível origem da diferença.  Mais uma vez, a metodologia da pesquisa subjacente é crucial para avaliar a confiabilidade dos dados.
#
#
# **Pontos a serem investigados para uma análise mais completa:**
#
# * **Metodologia dos estudos:** Como as pesquisas foram conduzidas?  Qual o tamanho da amostra?  Como a IA foi definida (existem muitas aplicações)?  A margem de erro é significativa?
# * **Tipos de IA utilizados:** Quais tipos de IA são empregados na saúde brasileira?  (ex: diagnóstico por imagem, análise de dados de pacientes, robótica cirúrgica, etc.)
# * **Barreiras à adoção:** Quais são os principais desafios para a maior adoção da IA na saúde no Brasil? (ex: custos, regulamentação, falta de treinamento, infraestrutura, etc.)
# * **Impacto da IA na saúde:** Quais são os benefícios e os riscos da IA na saúde brasileira?  (ex: melhoria na precisão de diagnósticos, redução de custos, aumento da eficiência, privacidade de dados, vieses algorítmicos, etc.)
# * **Comparação internacional:** Como o Brasil se compara a outros países em termos de adoção de IA na saúde?
#
#
# Em resumo, os resultados da busca oferecem um ponto de partida, mas são insuficientes para uma compreensão completa do tema.  Mais pesquisa é necessária para obter uma análise mais robusta e informativa sobre a IA na saúde no Brasil.
#
# [Analista] Executando: Analisar os dados encontrados
# [Analista] Executando: Analisar os dados encontrados
# [Analista] Resultado: A pesquisa inicial sobre a adoção de Inteligência Artificial (IA) na saúde no Brasil aponta para uma penetração baixa, mas com dados conflitantes e fragmentados que demandam investigação mais aprofundada.  As principais conclusões e pontos a serem analisados são:
#
# **Conclusões Preliminares:**
#
# * **Baixa Adoção:**  As fontes indicam uma adoção limitada de IA, com estimativas variando:  17% dos médicos e 16% dos enfermeiros usando IA em um estudo, e 4% dos estabelecimentos de saúde em outro.  Essa discrepância aponta para a necessidade de uma análise crítica da metodologia de cada pesquisa.  A baixa adoção sugere que a IA ainda não é uma ferramenta amplamente integrada no sistema de saúde brasileiro.
#
# * **Fontes Conflitantes e Limitadas:** As informações provêm de diferentes fontes (Upflux, SBIS, G1), mas a falta de acesso ao estudo completo do Upflux e a ausência de detalhes metodológicos nos estudos do SBIS e G1 impedem uma avaliação completa da confiabilidade dos dados.  As porcentagens apresentadas precisam ser contextualizadas com informações sobre tamanho da amostra, metodologia de coleta de dados, margem de erro e definição precisa do que constitui "uso de IA" no contexto da pesquisa.
#
# **Pontos Cruciais a Investigar:**
#
# * **Metodologia dos Estudos:**  É fundamental analisar o rigor metodológico das pesquisas citadas, incluindo o tamanho da amostra, a representatividade da amostra em relação à população brasileira (considerando diferentes regiões e tipos de estabelecimentos de saúde), a definição operacional de "uso de IA" (que tipos de aplicações foram consideradas?), e a margem de erro.  A falta de transparência metodológica compromete a confiabilidade dos resultados.
#
# * **Tipos de IA utilizados:** A pesquisa precisa especificar os tipos de IA em uso no Brasil.  São sistemas de diagnóstico por imagem, ferramentas de análise preditiva de dados de pacientes, assistentes virtuais, robótica cirúrgica, ou outros?  A diversidade de aplicações da IA na saúde exige uma classificação detalhada para uma compreensão mais precisa.
#
# * **Barreiras à Adoção:**  A baixa adoção provavelmente é influenciada por diversas barreiras.  A investigação precisa identificar os principais obstáculos, incluindo:  custos de implementação e manutenção, falta de infraestrutura tecnológica adequada, regulamentações e políticas públicas, falta de treinamento e capacitação de profissionais de saúde, preocupações com segurança e privacidade de dados, e resistência cultural à adoção de novas tecnologias.
#
# * **Benefícios e Riscos:** A análise deve explorar os benefícios observados (melhora na precisão diagnóstica, eficiência operacional, redução de custos, etc.) e os potenciais riscos (vieses algorítmicos, privacidade de dados, dependência tecnológica, etc.) da implementação da IA na saúde no Brasil.
#
# * **Comparação Internacional:**  Comparar a taxa de adoção de IA na saúde no Brasil com outros países pode fornecer um contexto importante, permitindo identificar lacunas e melhores práticas.
#
# **Conclusão:**
#
# Em resumo, a pesquisa inicial indica uma adoção limitada da IA na saúde no Brasil.  No entanto, a falta de dados detalhados e a inconsistência entre as fontes disponíveis impedem conclusões definitivas.  Uma investigação mais completa, baseada em estudos científicos robustos e dados quantitativos e qualitativos confiáveis, é essencial para compreender a real situação e o potencial da IA no sistema de saúde brasileiro.  A análise deve ir além de simples porcentagens e explorar as complexas dimensões tecnológicas, econômicas, sociais e éticas envolvidas na adoção da IA neste setor.
#
# [Analista] Resultado: A análise dos dados sobre a adoção de Inteligência Artificial (IA) na saúde no Brasil, extraída de diferentes fontes (Upflux, SBIS e G1), revela uma situação de baixa penetração da tecnologia, mas com informações fragmentadas e inconsistentes que requerem investigação mais aprofundada.
#
# **Pontos Fortes da Análise:**
#
# * **Identificação da baixa adoção:**  As fontes convergem na constatação de uma baixa adoção de IA na saúde brasileira, com percentuais variando entre 4% e 17% para diferentes atores (hospitais e médicos).  Isso aponta para um estágio inicial de desenvolvimento.
# * **Identificação de fontes:** A pesquisa utilizou múltiplas fontes, indicando um esforço para obter informações diversificadas.
# * **Consciência das limitações:** A análise reconhece explicitamente as limitações dos dados disponíveis, destacando a necessidade de acessar os estudos originais e buscar fontes adicionais para uma análise completa.
# * **Definição de próximos passos:**  A análise apresenta um plano claro para aprofundar a pesquisa, incluindo acessar links, buscar artigos científicos em bases de dados relevantes e analisar relatórios de mercado.  A sugestão de investigar diferentes aplicações de IA em áreas específicas da saúde é também um ponto positivo.
#
# **Pontos Fracos da Análise:**
#
# * **Inconsistências nos dados:** As porcentagens de adoção apresentadas são conflitantes (4% vs 17% para estabelecimentos de saúde, por exemplo).  A análise menciona a necessidade de investigar a origem dessa discrepância, mas não a faz.
# * **Superficialidade na análise das fontes:** Embora mencione a necessidade de analisar a metodologia dos estudos, a análise não realiza uma avaliação crítica das fontes.  A confiabilidade das informações apresentadas é questionável sem uma avaliação da metodologia (tamanho da amostra, representatividade, etc.) de cada pesquisa.
# * **Falta de contextualização:** A análise não discute o contexto socioeconômico e infraestrutural que pode influenciar a adoção de IA na saúde no Brasil.  Fatores como a desigualdade de acesso à tecnologia e a disponibilidade de infraestrutura de TI são cruciais para uma análise completa.
# * **Ausência de dados qualitativos:** A análise se concentra principalmente em dados quantitativos (percentuais de adoção).  A falta de informações qualitativas sobre as experiências dos profissionais de saúde, os desafios enfrentados e os benefícios percebidos limita a compreensão da situação.
#
#
# **Recomendações para melhoria da análise:**
#
# * **Acesso e análise detalhada dos links:**  A análise deve ir além da simples menção da necessidade de acessar os links, e de fato acessar e analisar o conteúdo de cada um deles, incluindo a metodologia utilizada, o tamanho da amostra e as limitações dos estudos.
# * **Avaliação crítica das fontes:**  A análise precisa avaliar a credibilidade e o rigor metodológico de cada fonte, considerando fatores como a reputação da publicação, o método de coleta de dados e a possível presença de vieses.
# * **Inclusão de dados qualitativos:**  Buscar informações qualitativas sobre a experiência de profissionais e pacientes com a IA na saúde brasileira.
# * **Contextualização socioeconômica:**  Considerar fatores socioeconômicos e infraestruturais que influenciam a adoção de IA na saúde no Brasil.
# * **Comparação com outros países:**  Incluir uma análise comparativa da adoção de IA na saúde no Brasil em relação a outros países, para contextualizar a situação brasileira.
#
# Em resumo, a análise apresenta um bom início, identificando a baixa adoção de IA na saúde no Brasil e a necessidade de mais pesquisa. No entanto, a análise deve aprofundar a investigação das fontes, resolver as inconsistências nos dados e incluir dados qualitativos e contextualização para fornecer uma visão mais completa e robusta da situação.
#
# [Escritor] Executando: Gerar relatório executivo
# [Escritor] Resultado: ## Relatório Executivo: Adoção de Inteligência Artificial na Saúde no Brasil
#
# **Data:** 2023-10-27
#
# **Introdução:**
#
# Este relatório resume a análise preliminar sobre a adoção de Inteligência Artificial (IA) no setor de saúde brasileiro, baseada em dados de fontes diversas (Upflux, SBIS e G1). A análise revela uma penetração baixa e inconsistências significativas nos dados disponíveis, demandando investigação mais aprofundada.
#
# **Principais Constatacões:**
#
# * **Baixa Penetração:**  As fontes indicam uma adoção limitada de IA, com estimativas conflitantes variando entre 4% e 17% dependendo do grupo analisado (médicos, enfermeiros ou estabelecimentos de saúde). Essa disparidade destaca a necessidade de análise criteriosa da metodologia de cada pesquisa.  A baixa adoção aponta para um estágio inicial de desenvolvimento da IA no sistema de saúde brasileiro.
#
# * **Dados Fragmentados e Inconsistentes:** A falta de acesso aos estudos completos e a ausência de detalhes metodológicos nos estudos analisados impedem uma avaliação completa da confiabilidade dos dados.  A ausência de transparência metodológica (tamanho da amostra, representatividade, definição de "uso de IA") compromete a confiabilidade dos resultados quantitativos.
#
# **Pontos Críticos a Investigar:**
#
# * **Metodologia das Pesquisas:**  Analisar rigorosamente a metodologia de cada estudo, incluindo tamanho da amostra, representatividade geográfica e da diversidade de instituições de saúde, definição operacional de "uso de IA", e margem de erro.
#
# * **Tipos de IA Utilizados:** Detalhar os tipos específicos de IA aplicados (diagnóstico por imagem, análise preditiva, robótica cirúrgica, etc.) para uma compreensão mais precisa da penetração da tecnologia.
#
# * **Barreiras à Adoção:** Identificar os principais obstáculos à adoção, incluindo: custos de implementação e manutenção, falta de infraestrutura tecnológica, regulamentações, falta de treinamento, preocupações com segurança e privacidade de dados, e resistência cultural.
#
# * **Benefícios e Riscos:** Avaliar os benefícios (melhoria de diagnósticos, eficiência, redução de custos) e riscos (vieses algorítmicos, privacidade, dependência tecnológica) da implementação da IA no sistema de saúde.
#
# * **Comparação Internacional:** Contextualizar a adoção brasileira comparando-a com a de outros países, identificando lacunas e melhores práticas.
#
# * **Dados Qualitativos:** Incluir dados qualitativos para enriquecer a análise, considerando a experiência de profissionais e pacientes.
#
# **Recomendações:**
#
# * **Aprofundamento da Pesquisa:**  Recomenda-se acesso e análise detalhada dos estudos originais para validar os dados e esclarecer as inconsistências.
#
# * **Busca por Dados Adicionais:** Expandir a pesquisa para incluir mais fontes, especialmente estudos científicos publicados em bases de dados confiáveis e relatórios de mercado.
#
# * **Análise Multifacetada:**  Integrar dados quantitativos e qualitativos para uma compreensão completa do cenário.
#
# * **Contextualização:** Considerar o contexto socioeconômico e infraestrutural do Brasil para interpretar melhor os resultados.
#
# **Conclusão:**
#
# A análise preliminar indica uma baixa adoção de IA na saúde no Brasil, com dados inconsistentes que exigem investigação mais profunda.  A pesquisa futura deve focar em uma análise metodológica rigorosa e na inclusão de dados qualitativos para fornecer uma visão mais completa e robusta do cenário, permitindo uma tomada de decisão informada sobre investimentos e políticas públicas no setor.  Uma compreensão completa é crucial para aproveitar o potencial da IA para melhorar a saúde e a eficiência do sistema de saúde brasileiro.

# %%
# Case de Uso 1: Análise de Tendências de Mercado
async def case_mercado():
    print("\n=== Case 1: Análise de Tendências de Mercado ===")
    memory = ContextualMemory(max_context_size=5)
    model = GeminiModel(temperature=0.8, top_k=50)
    search_tool = GoogleSearchTool()

    pesquisador = Agent(name="Pesquisador", role="Busca dados", model=model, tools=[search_tool], memory=memory)
    analista = Agent(name="Analista", role="Analisa dados", model=model, memory=memory)
    escritor = Agent(name="Escritor", role="Escreve relatório", model=model, memory=memory)

    tarefa_pesquisa = Task(description="Buscar dados sobre tendências em tecnologias verdes em 2025", agent=pesquisador, priority=2)
    tarefa_analise = Task(description="Analisar os dados encontrados", agent=analista, priority=1, dependencies=[tarefa_pesquisa])
    tarefa_relatorio = Task(description="Gerar relatório executivo", agent=escritor, priority=0, dependencies=[tarefa_analise])

    equipe = Crew(agents=[pesquisador, analista, escritor], tasks=[tarefa_pesquisa, tarefa_analise, tarefa_relatorio])
    await equipe.run()

# Executa os dois cases no Colab
async def main():
    await case_mercado()

if __name__ == "__main__":
    await main()
# Out:
# === Case 1: Análise de Tendências de Mercado ===
# [Pesquisador] Executando: Buscar dados sobre tendências em tecnologias verdes em 2025
# [Pesquisador] Executando: Buscar dados sobre tendências em tecnologias verdes em 2025
# [Pesquisador] Executando: Buscar dados sobre tendências em tecnologias verdes em 2025
# [Pesquisador] Resultado: Os resultados da busca indicam que as tendências em tecnologias verdes para 2025 incluem:
#
# * **Automação e Tecnologias Verdes:**  A combinação de automação com soluções sustentáveis é apontada como uma tendência forte.  Isso provavelmente inclui automação em processos de produção mais limpos, monitoramento ambiental automatizado, e otimização de recursos através de sistemas inteligentes.  (Fonte: Sebrae)
#
# * **Tecnologia Sustentável em geral:**  As fontes consultadas reforçam a ideia de que a tecnologia sustentável como um todo continuará sendo uma tendência forte em 2025. Isso abrange uma gama ampla de inovações, sem especificar áreas específicas além da automação. (Fonte: SIDI)
#
# * **Tendências interligadas:**  Uma das fontes menciona "tecnologia e sustentabilidade" juntas, sugerindo que as tecnologias verdes não são um setor isolado, mas estão integradas a outras tendências tecnológicas.  (Fonte: LinkedIn)
#
#
# **Limitações:**
#
# Os resultados são limitados em termos de detalhe e profundidade.  Eles apontam para tendências gerais, mas faltam informações específicas sobre tecnologias específicas, seus impactos e projeções de crescimento.  Seria necessário consultar mais fontes para obter um panorama mais completo das tendências em tecnologias verdes para 2025.  Por exemplo,  falta informação sobre:
#
# * **Energias renováveis específicas:**  Qual o crescimento esperado para solar, eólica, geotérmica, hidrogênio verde, etc.?
# * **Materiais sustentáveis:**  Quais inovações em biomateriais, reciclagem e economia circular são esperadas?
# * **Agricultura sustentável:**  Quais tecnologias de precisão e monitoramento ambiental estão se tornando dominantes?
# * **Gestão de recursos hídricos:**  Quais avanços em tecnologias para tratamento e gestão de água são esperados?
# * **Mobilidade sustentável:**  Quais inovações em veículos elétricos, transporte público inteligente e infraestrutura sustentável são previstas?
#
#
# Em resumo, enquanto os resultados fornecem uma visão geral positiva da importância das tecnologias verdes em 2025, é crucial buscar fontes mais detalhadas para uma análise completa e precisa.
#
# [Pesquisador] Resultado: Os resultados da busca indicam que as tendências em tecnologias verdes em 2025 incluem:
#
# * **Automação e tecnologias verdes:**  A agência Sebrae destaca a automatização como uma tendência importante, integrando-a com tecnologias verdes.  Isso sugere a utilização de tecnologias automatizadas para otimizar processos sustentáveis, possivelmente em áreas como energia renovável, gestão de recursos hídricos ou agricultura sustentável.
#
# * **Energia renovável:** Embora não explicitamente mencionado em todos os links, a energia renovável é uma tendência implícita e provavelmente um componente chave das tecnologias verdes em 2025.  A menção à sustentabilidade e tecnologias verdes implica fortemente a continuação do desenvolvimento e adoção de fontes de energia renováveis.
#
# * **Tecnologia e sustentabilidade:** A ligação entre tecnologia e sustentabilidade é um tema recorrente.  As tecnologias verdes não são vistas como um setor isolado, mas como um elemento essencial para a inovação e a transformação sustentável em diversos setores.
#
# **Pontos a melhorar na análise:**
#
# Os resultados são superficiais.  Para uma análise mais completa, seria necessário:
#
# * **Acesso ao conteúdo dos links:** A análise se baseia apenas nos títulos e fontes.  O acesso ao conteúdo completo de cada artigo permitiria uma compreensão mais profunda das tendências e sua especificidade.
# * **Mais fontes:** Três fontes são poucas para uma análise robusta.  Uma busca mais ampla em diferentes bancos de dados e plataformas (ex: artigos científicos, relatórios de consultoria) aumentaria a confiabilidade dos resultados.
# * **Especificidade das tendências:**  A informação é bastante genérica.  Uma análise mais detalhada poderia identificar tendências específicas dentro das tecnologias verdes, como:
#     * **Inteligência Artificial aplicada à sustentabilidade:**  Monitoramento ambiental, otimização de recursos, previsão de eventos climáticos.
#     * **Biotecnologia verde:** Biocombustíveis, biomateriais, bioremediação.
#     * **Economia circular:**  Gestão de resíduos, reciclagem, reutilização de materiais.
#     * **Construção sustentável:**  Materiais eco-eficientes, edifícios de baixo consumo energético.
#
#
# Em resumo, a análise inicial indica que as tecnologias verdes em 2025 se caracterizam pela integração com a automação e uma crescente necessidade de soluções tecnológicas para atingir metas de sustentabilidade em diversos setores.  No entanto, a análise necessita de aprofundamento para fornecer um panorama mais preciso e completo.
#
# [Pesquisador] Resultado: Os resultados da busca apontam para algumas tendências em tecnologias verdes em 2025, embora sejam limitados em detalhe e profundidade.  Precisamos analisar cada link individualmente para extrair informações mais precisas. No entanto, baseado nos títulos, podemos inferir algumas tendências:
#
# * **Automação e Tecnologias Verdes:**  A ligação com a Agência Sebrae sugere uma forte integração da automação com tecnologias sustentáveis, provavelmente em processos industriais e de produção.  Isso pode incluir robótica, IA e IoT aplicadas à otimização de recursos e redução de impacto ambiental.
#
# * **Tecnologias Sustentáveis como Tendência Forte:** A menção da SIDI reforça a ideia da continuidade e crescimento da demanda por soluções tecnológicas sustentáveis, indicando um mercado em expansão.  Não especifica tecnologias específicas, mas indica um panorama geral positivo.
#
# * **Tecnologia e Sustentabilidade Integradas:** O artigo do LinkedIn sugere uma visão mais ampla, conectando tecnologia e sustentabilidade em um contexto mais amplo, que pode incluir setores diversos, possivelmente além da indústria.
#
# **Para um panorama mais completo, é necessário:**
#
# * **Analisar o conteúdo de cada link:**  Ler os artigos completos fornecerá uma compreensão mais detalhada das tendências mencionadas, incluindo exemplos específicos de tecnologias, setores afetados e previsões mais concretas.
# * **Ampliar a busca:** Utilizar outras ferramentas de busca e palavras-chave mais específicas (ex: "tecnologias verdes 2025 + energia renovável", "tecnologias verdes 2025 + agricultura sustentável", etc.) para obter resultados mais focados.
# * **Consultar relatórios de especialistas:**  Organizações como a ONU, agências governamentais e consultorias especializadas em sustentabilidade frequentemente publicam relatórios e previsões sobre tendências tecnológicas verdes.
#
# Em resumo, os resultados iniciais indicam um cenário positivo para as tecnologias verdes em 2025, com foco na automação e integração com diversos setores. No entanto, é necessário uma análise mais aprofundada para identificar tendências mais específicas e detalhadas.
#
# [Analista] Executando: Analisar os dados encontrados
# [Analista] Executando: Analisar os dados encontrados
# [Analista] Resultado: A análise dos dados revela uma tendência forte e crescente em tecnologias verdes para 2025, mas com limitações significativas em termos de profundidade e especificidade.  As três fontes analisadas convergem em alguns pontos principais:
#
# **Tendências Identificadas (com limitações):**
#
# * **Automação e Tecnologias Verdes:**  Esta é a tendência mais consistente, apontada por todas as fontes.  A automação será crucial para otimizar processos sustentáveis, integrando-se a tecnologias verdes em diversos setores (indústria, agricultura, gestão de recursos).  As tecnologias envolvidas podem incluir robótica, Inteligência Artificial (IA) e Internet das Coisas (IoT).
#
# * **Tecnologias Sustentáveis como Tendência Geral:** A demanda por soluções tecnológicas sustentáveis como um todo continuará crescendo.  Esta é uma observação ampla, sem detalhamento de áreas específicas além da automação.
#
# * **Integração entre Tecnologia e Sustentabilidade:** As tecnologias verdes não são vistas como um setor isolado, mas como parte integrante da inovação e transformação sustentável em vários setores.  Isso implica em uma abordagem holística, com tecnologias verdes impactando diferentes áreas.
#
#
# **Limitações da Análise e Necessidades de Aprimoramento:**
#
# A análise apresentada sofre de diversas limitações, incluindo:
#
# * **Superficialidade da Informação:** As fontes consultadas fornecem uma visão geral, sem aprofundamento em tecnologias específicas, impactos e projeções de crescimento.  A análise se baseia em informações superficiais, muitas vezes inferidas apenas dos títulos dos artigos.
#
# * **Falta de Detalhes:**  Informações cruciais estão ausentes, tais como:
#     * Projeções de crescimento para energias renováveis específicas (solar, eólica, etc.).
#     * Inovações em materiais sustentáveis, biotecnologia e economia circular.
#     * Avanços em agricultura sustentável e gestão de recursos hídricos.
#     * Inovações em mobilidade sustentável (veículos elétricos, transporte público).
#
# * **Número limitado de Fontes:**  A análise se baseia em apenas três fontes, o que limita a robustez e a abrangência dos resultados.
#
# * **Acesso limitado ao conteúdo:**  A análise se baseia em informações superficiais, sem acesso completo ao conteúdo dos artigos originais.
#
# **Recomendações para uma Análise Mais Completa:**
#
# Para melhorar a análise, as seguintes ações são recomendadas:
#
# * **Acesso ao conteúdo completo das fontes:** Ler os artigos completos permitirá uma compreensão mais profunda das tendências e detalhes específicos.
#
# * **Ampliação da busca:** Utilizar mais fontes, incluindo artigos científicos, relatórios de consultoria e publicações de organizações internacionais (ONU, etc.), com palavras-chave mais específicas para focar em áreas de interesse (ex: "tecnologias verdes 2025 + energia solar").
#
# * **Análise mais detalhada por setor:**  Dividir a análise por setores (energia, agricultura, indústria, transportes) permitirá uma visão mais específica das tendências em cada área.
#
# * **Incorporação de dados quantitativos:** Incluir dados quantitativos (projeções de mercado, investimentos, etc.) aumentará a precisão e a confiabilidade da análise.
#
#
# Em resumo, embora a análise inicial indique um futuro promissor para as tecnologias verdes em 2025, principalmente pela integração da automação, é crucial um aprofundamento significativo da pesquisa para obter um panorama completo, preciso e detalhado.
#
# [Analista] Resultado: A análise dos dados revela uma tendência crescente e positiva para as tecnologias verdes em 2025, mas com limitações significativas em termos de detalhe e profundidade.  As fontes consultadas apontam para três tendências principais:
#
# **1. Automação e Tecnologias Verdes:** Esta é uma tendência recorrente, destacada pela referência ao Sebrae.  A automação, incluindo robótica, IA e IoT, será integrada a processos de produção mais limpos, monitoramento ambiental e otimização de recursos.  A análise, porém, carece de exemplos concretos de aplicação dessa integração em setores específicos.
#
# **2. Tecnologias Sustentáveis como Tendência Geral:** A menção à SIDI reforça a visão de um mercado em expansão para tecnologias sustentáveis, sem especificar tecnologias ou setores.  Essa generalização precisa ser complementada com dados mais específicos.
#
# **3. Integração entre Tecnologia e Sustentabilidade:**  A referência ao LinkedIn indica que as tecnologias verdes não são um setor isolado, mas estão intrinsecamente ligadas a outras tendências tecnológicas e setores econômicos.  Essa observação é importante, mas novamente falta detalhe sobre a natureza dessas conexões.
#
#
# **Limitações da Análise:**
#
# A principal limitação é a falta de profundidade e especificidade.  As conclusões se baseiam em fontes que oferecem apenas uma visão geral.  Para uma análise mais robusta, são necessários:
#
# * **Acesso ao conteúdo completo das fontes:** A análise atual se baseia em inferências a partir de títulos e nomes de fontes, o que é insuficiente.
# * **Mais fontes de informação:**  Três fontes são insuficientes para uma análise confiável.  Seria necessário consultar relatórios de especialistas (ONU, agências governamentais, consultorias), artigos científicos e dados estatísticos.
# * **Especificação das tecnologias:** A análise precisa detalhar tecnologias específicas dentro das áreas de energia renovável (solar, eólica, hidrogênio verde), materiais sustentáveis, agricultura sustentável, gestão de recursos hídricos e mobilidade sustentável.  A menção à inteligência artificial, biotecnologia verde, economia circular e construção sustentável é crucial para aprofundar a análise.
#
#
# **Recomendações:**
#
# Para obter uma análise mais completa e precisa das tendências em tecnologias verdes para 2025, recomenda-se:
#
# 1. **Acessar e analisar o conteúdo completo das fontes já identificadas.**
# 2. **Expandir a busca utilizando outras bases de dados e plataformas.**
# 3. **Utilizar palavras-chave mais específicas na busca.**
# 4. **Consultar relatórios e estudos de especialistas em sustentabilidade e tecnologia.**
# 5. **Categorizar as tecnologias verdes por setor (energia, agricultura, transporte, etc.) para uma análise mais estruturada.**
#
#
# Em resumo, embora a análise inicial aponte para um futuro promissor para as tecnologias verdes, um estudo mais aprofundado é crucial para uma compreensão completa e precisa das tendências e oportunidades para 2025.
#
# [Escritor] Executando: Gerar relatório executivo
# [Escritor] Resultado: ## Relatório Executivo: Tendências em Tecnologias Verdes para 2025
#
# **Data:** 2023-10-27
#
# **Introdução:**
#
# Este relatório apresenta uma análise preliminar das tendências em tecnologias verdes projetadas para 2025, com base em uma pesquisa inicial. A análise identificou tendências promissoras, mas também revelou importantes limitações na profundidade e especificidade da informação disponível.  Um estudo mais aprofundado é recomendado para uma compreensão completa e acurada.
#
# **Tendências Identificadas (Análise Preliminar):**
#
# A pesquisa inicial aponta para três tendências principais, embora com detalhes limitados:
#
# 1. **Automação e Tecnologias Verdes:**  A integração da automação (robótica, IA, IoT) com tecnologias sustentáveis em processos industriais e de produção é uma tendência forte.  Esta integração visa otimizar recursos e reduzir o impacto ambiental.  No entanto, faltam exemplos concretos de sua aplicação em diferentes setores.
#
# 2. **Crescimento do Mercado de Tecnologias Sustentáveis:**  A demanda por soluções tecnológicas sustentáveis está em expansão.  Esta é uma observação geral, sem especificação de tecnologias ou setores além da automação.
#
# 3. **Integração Holística de Tecnologia e Sustentabilidade:** As tecnologias verdes não são vistas como um setor isolado, mas como parte integrante da inovação e transformação sustentável em diversos setores.  Esta observação carece de detalhes sobre a natureza dessas conexões intersetoriais.
#
#
# **Limitações da Análise:**
#
# A análise apresentada sofre de limitações significativas:
#
# * **Superficialidade:** A pesquisa se baseou em informações superficiais, muitas vezes inferidas apenas de títulos e resumos de artigos.
# * **Falta de Detalhes:**  Informações cruciais estão ausentes, incluindo projeções de crescimento para energias renováveis específicas, inovações em materiais sustentáveis e biotecnologia, avanços em agricultura sustentável, e inovações em mobilidade sustentável.
# * **Número Limitado de Fontes:** A análise se baseou em um número reduzido de fontes, limitando a robustez e a abrangência dos resultados.
# * **Acesso Limitado ao Conteúdo:** A análise não teve acesso completo ao conteúdo das fontes originais.
#
#
# **Recomendações:**
#
# Para obter uma análise completa e precisa, as seguintes ações são recomendadas:
#
# * **Aprofundamento da Pesquisa:** Analisar o conteúdo completo das fontes iniciais e expandir a busca para incluir relatórios de especialistas (ONU, agências governamentais, consultorias), artigos científicos e dados estatísticos.
# * **Especificação de Tecnologias:** Detalhar tecnologias específicas dentro de áreas como energia renovável (solar, eólica, hidrogênio verde), materiais sustentáveis, agricultura sustentável, gestão de recursos hídricos e mobilidade sustentável.
# * **Análise Setorial:** Categorizar as tecnologias verdes por setor (energia, agricultura, transporte, etc.) para uma análise mais estruturada.
# * **Incorporação de Dados Quantitativos:** Incluir dados quantitativos (projeções de mercado, investimentos, etc.) para aumentar a precisão e confiabilidade da análise.
#
#
# **Conclusão:**
#
# Embora a análise preliminar indique um futuro promissor para as tecnologias verdes em 2025, principalmente pela integração da automação, é crucial um aprofundamento significativo da pesquisa para obter um panorama completo, preciso e detalhado.  A realização das recomendações acima permitirá uma avaliação mais robusta e informativa das oportunidades e desafios neste setor em crescimento.

# %%
# Case de Uso 2: Planejamento Educacional
async def case_educacao():
    print("\n=== Case 2: Planejamento Educacional ===")
    memory = ContextualMemory(max_context_size=5)
    model = GeminiModel(temperature=0.8, top_k=50)
    search_tool = GoogleSearchTool()

    pesquisador = Agent(name="Pesquisador", role="Busca dados", model=model, tools=[search_tool], memory=memory)
    analista = Agent(name="Analista", role="Analisa dados", model=model, memory=memory)
    escritor = Agent(name="Escritor", role="Escreve relatório", model=model, memory=memory)

    tarefa_pesquisa = Task(description="Buscar dados sobre IA na educação em 2025", agent=pesquisador, priority=2)
    tarefa_analise = Task(description="Analisar os dados encontrados", agent=analista, priority=1, dependencies=[tarefa_pesquisa])
    tarefa_relatorio = Task(description="Gerar relatório executivo", agent=escritor, priority=0, dependencies=[tarefa_analise])

    equipe = Crew(agents=[pesquisador, analista, escritor], tasks=[tarefa_pesquisa, tarefa_analise, tarefa_relatorio])
    await equipe.run()

# Executa os dois cases no Colab
async def main():
    await case_educacao()

if __name__ == "__main__":
    await main()
# Out:
# === Case 2: Planejamento Educacional ===
# [Pesquisador] Executando: Buscar dados sobre IA na educação em 2025
# [Pesquisador] Executando: Buscar dados sobre IA na educação em 2025
# [Pesquisador] Executando: Buscar dados sobre IA na educação em 2025
# [Pesquisador] Resultado: Os resultados da busca fornecem algumas informações sobre IA na educação em 2025, mas são limitados e precisam de uma análise mais crítica.  Vamos detalhar:
#
# * **UNESCO (primeiro link):**  Esse link provavelmente levará a um artigo da UNESCO sobre o Dia Internacional da Educação em 2025.  É crucial verificar se o artigo realmente aborda a IA na educação especificamente, ou se apenas menciona a IA como uma das muitas tecnologias relevantes para a educação naquele ano.  A UNESCO publica frequentemente sobre tecnologias na educação, mas a menção à IA em um artigo sobre o Dia Internacional da Educação não garante um foco profundo sobre o tema em 2025.
#
# * **IT Forum (segundo link):**  Este link provavelmente contém uma coluna de opinião ou um artigo sobre tendências de IA na educação em 2025.  Artigos de opinião podem apresentar perspectivas tendenciosas ou especulativas.  A precisão e a confiabilidade da informação dependem da credibilidade da fonte e do rigor da análise apresentada.
#
# * **Forbes Brasil (terceiro link):**  Este link, vindo da Forbes Brasil, sugere um artigo sobre como a IA pode transformar o futuro da educação.  A Forbes é uma fonte confiável em termos de notícias de negócios, mas a abordagem pode ser mais centrada no impacto comercial da IA na educação do que em uma análise abrangente de seu uso pedagógico.  É importante avaliar o conteúdo para entender a profundidade e o foco do artigo.
#
# **Em resumo:**  Os resultados da busca oferecem um ponto de partida, mas não fornecem dados concretos sobre IA na educação em 2025.  Para obter informações mais precisas e detalhadas, é necessário:
#
# * **Acessar e ler os artigos:**  É fundamental analisar o conteúdo de cada link para entender o escopo e a qualidade das informações.
# * **Avaliar a credibilidade das fontes:**  Considerar a reputação da fonte e a possível parcialidade do autor.
# * **Buscar mais fontes:**  Realizar buscas adicionais utilizando diferentes palavras-chave e plataformas de pesquisa, buscando relatórios, estudos acadêmicos e artigos científicos sobre o tema.
# * **Filtrar informações:**  Distinguir entre previsões, tendências e dados concretos.
#
# Sem acessar e analisar o conteúdo de cada link, é impossível resumir os dados sobre IA na educação em 2025 encontrados.  A tarefa requer uma análise mais aprofundada das fontes fornecidas.
#
# [Pesquisador] Resultado: Os resultados da busca fornecem alguns links relevantes, mas não oferecem um panorama completo da IA na educação em 2025.  As fontes apontam para previsões e tendências, mas não para dados concretos sobre a implementação e impacto da IA na educação nesse ano específico.  Para obter dados mais robustos, seria necessário:
#
# * **Especificar o tipo de dados desejados:**  Estamos buscando dados quantitativos (estatísticas de uso, investimento, impacto em resultados de aprendizagem)?  Dados qualitativos (percepções de professores, alunos, administradores)?  Dados sobre implementações específicas em determinados países ou regiões?
#
# * **Pesquisar em bases de dados acadêmicas:**  Plataformas como Scopus, Web of Science e Google Scholar permitiriam encontrar artigos de pesquisa e relatórios que provavelmente conteriam dados mais detalhados e confiáveis do que artigos de notícias ou blogs.  A busca precisaria ser refinada com palavras-chave específicas, como "IA na educação", "aprendizagem com IA", "impacto da IA na educação",  combinadas com filtros de data (2025 ou próximo a 2025) e termos que especifiquem o tipo de dados desejado.
#
# * **Consultar relatórios de organizações internacionais:** Além da UNESCO, organizações como a OCDE e o Banco Mundial frequentemente publicam relatórios sobre tendências em educação, alguns dos quais podem incluir dados sobre o uso da IA.
#
# * **Analisar dados de empresas de tecnologia educacional:** Empresas que desenvolvem e implementam soluções de IA na educação podem ter dados internos sobre o uso de suas plataformas, embora o acesso a esses dados possa ser limitado.
#
#
# Em resumo, os links fornecidos são um ponto de partida, mas uma análise mais aprofundada usando as estratégias sugeridas acima é necessária para obter dados concretos sobre a IA na educação em 2025.  A ausência de dados concretos em 2023 sobre 2025 é compreensível, pois as previsões são baseadas em tendências atuais e projeções futuras.
#
# [Pesquisador] Resultado: Os resultados da busca fornecem alguns links relevantes, mas não oferecem uma visão completa da IA na educação em 2025.  A informação é esparsa e precisa de mais contexto e análise.  Vamos detalhar o que cada link *potencialmente* oferece:
#
# * **`https://www.unesco.org/pt/articles/unesco-dedica-o-dia-internacional-da-educacao-2025-inteligencia-artificial`**: Este link provavelmente contém um artigo da UNESCO sobre o Dia Internacional da Educação em 2025 e como a IA se relaciona com ele.  A UNESCO frequentemente publica relatórios e artigos sobre o uso da tecnologia na educação, então podemos esperar encontrar informações sobre políticas, tendências e desafios.  **Precisamos acessar o link para verificar o conteúdo.**
#
# * **`https://itforum.com.br/colunas/tendencias-ia-educacao-2025`**: Este link, de um site brasileiro de tecnologia, provavelmente apresenta um artigo de opinião ou análise sobre tendências da IA na educação em 2025.  Podemos esperar previsões, discussões sobre tecnologias específicas (como tutores inteligentes, sistemas de avaliação automatizados) e possivelmente, os impactos sociais e econômicos. **Precisamos acessar o link para verificar o conteúdo.**
#
# * **`https://forbes.com.br/forbes-tech/2025/03/como-a-ia-pode-transformar-o-futuro-da-educacao/`**:  Este link da Forbes Brasil provavelmente discute o potencial transformador da IA na educação em 2025.  Podemos esperar uma abordagem mais focada nos benefícios e oportunidades, mas possivelmente com menos ênfase nos desafios e riscos.  **Precisamos acessar o link para verificar o conteúdo.**
#
#
# **Conclusão:**
#
# Os links fornecem um ponto de partida para a pesquisa.  Para obter uma visão completa e precisa da IA na educação em 2025, é necessário acessar e analisar o conteúdo de cada link, além de complementar a pesquisa com outras fontes, como relatórios acadêmicos, artigos científicos e notícias de outras publicações confiáveis.  A informação presente nos links provavelmente não é exaustiva e pode representar apenas uma perspectiva particular sobre o tema.
#
# [Analista] Executando: Analisar os dados encontrados
# [Analista] Executando: Analisar os dados encontrados
# [Analista] Resultado: A análise dos dados encontrados revela uma necessidade crucial de acessar e analisar diretamente os links fornecidos antes de tirar conclusões definitivas sobre a IA na educação em 2025.  Os textos disponíveis descrevem apenas o *potencial* conteúdo dos links, sem acesso ao conteúdo real.  Portanto, a análise se limita a uma avaliação da *expectativa* em relação às fontes:
#
# **Pontos Fortes das Fontes Potenciais:**
#
# * **UNESCO:**  A UNESCO é uma fonte confiável e sua publicação sobre o Dia Internacional da Educação em 2025 pode fornecer informações valiosas sobre políticas e tendências oficiais em relação à IA na educação, embora não garanta um foco específico na IA.
#
# * **IT Forum:**  Como um portal de tecnologia, o IT Forum pode oferecer perspectivas de especialistas e análises de tendências, mas a natureza opinativa dos artigos exige uma avaliação crítica quanto à imparcialidade e rigor da informação.
#
# * **Forbes Brasil:**  A Forbes é uma fonte confiável de notícias de negócios, e seu artigo pode fornecer insights sobre o impacto comercial e o potencial de mercado da IA na educação.  No entanto, o foco pode ser mais empresarial do que pedagógico.
#
#
# **Pontos Fracos e Limitações:**
#
# * **Falta de dados concretos:**  As fontes parecem focar em previsões e tendências, não em dados concretos sobre a implementação e o impacto da IA na educação em 2025.  Isso é esperado, pois o ano em questão já passou e dados robustos podem ainda não estar totalmente compilados e disponíveis publicamente.
#
# * **Perspectivas limitadas:**  Cada fonte provavelmente oferecerá uma visão parcial do tema.  A UNESCO pode ter uma perspectiva política, o IT Forum uma perspectiva tecnológica e a Forbes uma perspectiva comercial.  Uma análise completa requer uma síntese de diferentes perspectivas.
#
# * **Necessidade de verificação da informação:**  É imprescindível acessar e analisar o conteúdo de cada link para verificar a precisão, a profundidade e o viés da informação apresentada.  As descrições atuais são apenas conjecturas.
#
# **Conclusão:**
#
# A análise preliminar indica que os links fornecidos oferecem um ponto de partida razoável, mas insuficiente para uma compreensão completa da IA na educação em 2025.  A análise completa só é possível após a verificação do conteúdo de cada link e a complementação da pesquisa com outras fontes mais abrangentes e robustas, como estudos acadêmicos e relatórios de organizações internacionais.  A pesquisa precisa ser expandida para incluir dados quantitativos e qualitativos, bem como diferentes perspectivas e contextos geográficos. A ausência de dados concretos em 2023 sobre 2025 é esperada, dada a natureza prospectiva do tema na época da pesquisa inicial.
#
# [Analista] Resultado: A análise dos dados encontrados revela uma lacuna significativa em informações concretas sobre a IA na educação em 2025.  Os três links fornecidos, embora promissores, oferecem apenas uma visão parcial e potencialmente tendenciosa do tema:
#
# * **UNESCO:** O link para a UNESCO *pode* conter informações relevantes, mas é necessário acessar e analisar o artigo para verificar se ele trata especificamente da IA na educação em 2025 ou apenas a menciona de forma tangencial em um contexto mais amplo sobre o Dia Internacional da Educação.  A abordagem da UNESCO provavelmente será focada em políticas educacionais e tendências globais.
#
# * **IT Forum:** Este link, provavelmente um artigo de opinião, oferece uma perspectiva potencialmente tendenciosa e especulativa sobre as tendências de IA na educação em 2025. A precisão e a confiabilidade dependem fortemente da credibilidade do autor e da solidez de sua análise.  A abordagem provavelmente se concentrará em previsões e tecnologias específicas.
#
# * **Forbes Brasil:** A Forbes, como fonte confiável, pode fornecer informações relevantes, mas sua perspectiva provavelmente será mais focada no impacto comercial e nas oportunidades de mercado da IA na educação do que em uma análise abrangente e equilibrada de seu uso pedagógico.
#
# **Em resumo:** Os links fornecem um ponto de partida, mas não fornecem dados concretos sobre a IA na educação em 2025. A informação é, no melhor dos casos, especulativa e baseada em projeções futuras, não em dados coletados em 2025.  Para obter uma análise mais completa e robusta, é crucial:
#
# 1. **Acessar e analisar o conteúdo de todos os links:**  Verificar o escopo, a profundidade e a confiabilidade das informações apresentadas em cada um.
#
# 2. **Buscar fontes adicionais:**  Ampliar a pesquisa para incluir relatórios acadêmicos, estudos científicos, dados quantitativos (estatísticas de implementação, investimento, etc.) e qualitativos (experiências de professores e alunos), relatórios de organizações internacionais (OCDE, Banco Mundial) e dados de empresas de tecnologia educacional.  A busca deve ser específica, utilizando palavras-chave refinadas e filtros de data.
#
# 3. **Avaliar a credibilidade das fontes:** Considerar a reputação da fonte, possíveis vieses e a metodologia utilizada na coleta e análise de dados.
#
# 4. **Distinguir entre previsões, tendências e dados concretos:**  É fundamental diferenciar entre projeções futuras e informações baseadas em evidências empíricas.
#
# Sem acessar os links e realizar uma pesquisa mais abrangente, é impossível fornecer uma análise conclusiva dos dados sobre IA na educação em 2025.  A ausência de dados concretos em 2023 sobre o ano de 2025 é esperada, pois se trata de uma previsão baseada em tendências e projeções.
#
# [Escritor] Executando: Gerar relatório executivo
# [Escritor] Resultado: ## Relatório Executivo: Inteligência Artificial na Educação em 2025
#
# **Data:** [Data de hoje]
#
# **Introdução:** Este relatório resume a análise preliminar de informações disponíveis sobre a implementação e o impacto da Inteligência Artificial (IA) na educação em 2025.  A pesquisa inicial se baseou em três links (UNESCO, IT Forum e Forbes Brasil) que, embora fornecessem um ponto de partida, apresentaram limitações significativas.
#
# **Metodologia:** A análise inicial focou na avaliação do *potencial* conteúdo dos links fornecidos, considerando a reputação das fontes e a natureza esperada das informações.  Devido à ausência de acesso direto ao conteúdo dos links, a avaliação se baseou em expectativas, não em dados concretos.
#
# **Principais Constatações:**
#
# * **Falta de Dados Concretos:** A pesquisa preliminar revelou uma escassez significativa de dados concretos sobre a IA na educação em 2025.  As informações disponíveis são, em sua maioria, projeções e análises especulativas, refletindo a natureza prospectiva do tema em 2023.  A ausência de dados robustos sobre 2025 é esperada, considerando a disponibilidade tardia de informações consolidadas sobre o impacto de tecnologias emergentes.
#
# * **Perspectivas Parciais:** As fontes analisadas oferecem perspectivas parciais e, potencialmente, tendenciosas:
#     * **UNESCO:** Foco em políticas e tendências globais.
#     * **IT Forum:** Foco em previsões e tecnologias específicas, com potencial viés opinativo.
#     * **Forbes Brasil:** Foco no impacto comercial e oportunidades de mercado.
#
# * **Necessidade de Pesquisa Adicional:** Para obter uma compreensão completa e robusta da IA na educação em 2025, é crucial expandir a pesquisa, incluindo:
#     * Acesso e análise completa do conteúdo dos três links.
#     * Busca por relatórios acadêmicos, estudos científicos, dados quantitativos e qualitativos (estatísticas de implementação, investimento, experiências de professores e alunos).
#     * Inclusão de informações de organizações internacionais como OCDE e Banco Mundial, além de dados de empresas de tecnologia educacional.
#     * Utilização de palavras-chave refinadas e filtros de data para pesquisas mais precisas.
#     * Avaliação crítica da credibilidade das fontes, considerando possíveis vieses e metodologias.
#     * Distinção entre previsões, tendências e dados concretos.
#
# **Recomendações:**
#
# * **Ampliar a Pesquisa:** Realizar uma pesquisa abrangente e sistemática, utilizando as fontes mencionadas acima, para reunir dados quantitativos e qualitativos sobre o tema.
# * **Analisar Dados Coletados:**  Após a coleta de dados, realizar uma análise detalhada, considerando as diferentes perspectivas e contextos geográficos.
# * **Elaborar Relatório Final:**  Produzir um relatório final completo, apresentando os dados coletados, a análise e as conclusões sobre a implementação e o impacto da IA na educação em 2025.
#
# **Conclusão:** A pesquisa inicial indica que a compreensão da IA na educação em 2025 requer uma investigação mais aprofundada e abrangente.  A pesquisa adicional recomendada fornecerá uma base sólida para conclusões mais precisas e informativas.  A expectativa é que dados concretos e robustos sobre o tema somente estarão amplamente disponíveis após um período de tempo considerável após 2025.
